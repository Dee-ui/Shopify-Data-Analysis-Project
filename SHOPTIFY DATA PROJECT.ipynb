# %% [markdown]
# ## Author: Dauda Agbonoga

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Crowntech\Documents\Projects\Project-20240414T150722Z-001\Project\Top Hits Spotify from 2000-2019\songs_normalize.csv",
                 encoding='latin1')
display(df)
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %%
import matplotlib.pyplot as plt
stats = df.groupby(by="Key")["Popularity"].sum()

stats
#visualising
stats.plot(kind="bar",color = ["g","blue"])
plt.xlabel("Key")
plt.ylabel("Popularity")
plt.title("Key VS Popularity")
plt.show()

# %% [markdown]
# # There are different musical Keys, they are represented by pitches(integers) E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1. The above chart state that songs with 1 = C♯/D♭ is the very popular on Shoptify.

# %%
import matplotlib.pyplot as plt

result=df.groupby(by="Mode")["Popularity"].sum()

result
# Out:
# Mode
# 0    51005
# 1    62343
# Name: Popularity, dtype: int64

# %%
result.plot(kind="pie")
# Out:
# <Axes: ylabel='Popularity'>

# %% [markdown]
# # The above pie chart shows that songs on Major Scale is More popular than songs on the Minor musical scale.

# %%
import matplotlib.pyplot as plt
stats = df.groupby(by="Explicit")["Speechiness"].sum()

stats
#visualising
stats.plot(kind="pie",color = ["blue","m"])
plt.xlabel("Explicity")
plt.ylabel("Speechiness")
plt.title("Explicity VS Speechiness")
plt.show()

# %% [markdown]
# # Speechiness detects the presence of spoken words in a track (e.g. talk show, audio book, poetry), the above chart shows that the speechiness is both acceptable by adult and children.

# %%
# Number visualization of Explicit and Popularity
import matplotlib.pyplot as plt

result=df.groupby(by="Explicit")["Speechiness"].sum()

result
# Out:
# Explicit
# False    109.4420
# True      89.2261
# Name: Speechiness, dtype: float64

# %%
import matplotlib.pyplot as plt

result=df.groupby(by="Mode")["Tempo"].sum()

result
# Out:
# Mode
# 0    100983.239
# 1    127667.612
# Name: Tempo, dtype: float64

# %%
result.plot(kind="bar")
# Out:
# <Axes: xlabel='Mode'>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating data
Key = df["Key"]
Popularity = df["Popularity"] 
Explicit = df["Explicit"] 
Speechiness = df["Speechiness"]  
Mode = df["Mode"]
Popularity = df["Popularity"]
Mode = df["Mode"]
Tempo = df["Tempo"]
# Creating subplots: 2 rows, 2 columns
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Bar plot
axs[0, 0].bar(Key, Popularity)
axs[0, 0].set_title('Key Vs Popularity')

# pie plot
axs[0, 1].pie(Explicit, Speechiness)
axs[0, 1].set_title('Explicit Vs Speechiness')

# pie chart
axs[1, 0].pie(Mode, Tempo)
axs[1, 0].set_title('Mode Vs Tempo')

# Area plot
axs[1, 1].bar(Mode, Popularity, color = 'blue')
axs[1, 1].set_title('Mode Vs Popularity')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 25
#      22 axs[0, 1].set_title('Explicit Vs Speechiness')
#      24 # pie chart
# ---> 25 axs[1, 0].pie(Mode, Tempo, color = 'm')
#      26 axs[1, 0].set_title('Mode Vs Tempo')
#      28 # Area plot
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:1486, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1483 @functools.wraps(func)
#    1484 def inner(ax, *args, data=None, **kwargs):
#    1485     if data is None:
# -> 1486         return func(
#    1487             ax,
#    1488             *map(sanitize_sequence, args),
#    1489             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1491     bound = new_sig.bind(ax, *args, **kwargs)
#    1492     auto_label = (bound.arguments.get(label_namer)
# ...

# %% [markdown]
# ### Introducing some discrepancies in the data

# %%
df.head()
# Out:
#            artist                    song  duration_ms  explicit  year  \
# 0  Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1       blink-182    All The Small Things       167066     False  1999
# 2      Faith Hill                 Breathe       250546     False  1999
# 3        Bon Jovi            It's My Life       224493     False  2000
# 4          *NSYNC             Bye Bye Bye       200560     False  2000
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
#
#    acousticness  instrumentalness  liveness  valence    tempo         genre
# ...

# %% [markdown]
# import numpy as np
# import random
# # 1. Introduce Missing Values
# # Randomly select 5% of the dataset and replace with NaN for specific columns
# cols_with_missing_values = ['explicit', 'danceability', 'energy', 'acousticness', 'liveness']
# for col in cols_with_missing_values:
#     df.loc[df.sample(frac=0.05).index, col] = np.nan
#
# # 2. Add Duplicate Rows
# # Randomly duplicate 3% of the rows
# duplicate_count = int(0.03 * len(df))
# duplicates = df.sample(n=duplicate_count)
# df = pd.concat([df, duplicates])
#
# # 3. Inconsistent Data Formats
#
# # Modify 'currency' to have inconsistent casing
# df['artist'] = df['artist'].apply(lambda x: x.lower() if random.random() > 0.5 else x.upper())
#
# # Modify 'product_price' to insert currency symbols inconsistently
# df['year'] = df['year'].apply(lambda x: f'${x}' if random.random() > 0.5 else x)
#
# # 4. Add Outliers or Erroneous Data
# # Add unrealistic product prices (negative or very high values)
# outlier_count = int(0.01 * len(df))
# outliers = df.sample(n=outlier_count).index
# df.loc[outliers, 'key'] = df.loc[outliers, 'key'].apply(lambda x: random.choice([-999.99, 99999.99]))
#
# # Add negative quantities or extremely high values
# df.loc[outliers, 'mode'] = df.loc[outliers, 'mode'].apply(lambda x: random.choice([-5, 10000]) if pd.notna(x) else x)
#
# # 5. Add Whitespace and Extra Characters
# # Add random whitespace to string columns like 'product_name'
# df['artist'] = df['artist'].apply(lambda x: f' {x} ' if pd.notna(x) and random.random() > 0.5 else x)
#
# import random
#
# # List of special characters to randomly add
# special_chars = ['#', '@', '$', '%', '&', '*', '!', '^']
#
# # Function to randomly add three special characters
# def add_special_chars(x):
#     chars_to_add = ''.join(random.choices(special_chars, k=3))  # Select 3 random characters
#     return f'{x}{chars_to_add}' if random.random() > 0.5 else f'{chars_to_add}{x}'
#
# # Add three special characters randomly to 'customer_id' and 'device_id'
# df['tempo'] = df['tempo'].apply(add_special_chars)
# df['genre'] = df['genre'].apply(add_special_chars)
# df['valence'] = df['valence'].apply(add_special_chars)
#
# # Save the modified dataset to a new CSV file
# output_file_path = 'raw_spotify_dataset.csv'
# #df.to_csv(output_file_path, index=False)
#
# print(f"Discrepant dataset created and saved to {output_file_path}")
#
# df.head(50)
